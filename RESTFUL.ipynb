# %% [markdown]
# ## Retrieving a document from a HTTP server
#
# ``` mermaid
# sequenceDiagram
#     participant client as HTTP client
#     participant server as HTTP server
#
#     client ->> server : request
#     server -->> client : response
# ```
#
# ``` mermaid
# flowchart LR
#     %% Bounding Nodes
#     start([start])
#     stop([stop])
#
#     %% Core processes
#     create["create socket
#         - address family: INET
#         - socket type: SOCK_STREAM"]
#     connect["connect socket to server"]
#     request["request page from server"]
#     close["close connection to server"]
#
#     %% Execution Path
#     start --> create --> connect
#     connect --> request --> response
#     response --> close --> stop
#
#     %% notes
#     note_for_create["SOCK STREAM: character device that processes character-by-character\n(not fixed size blocks)"]
#
#     %% Connect notes
#     note_for_create .- create
#
# ```

# %%
import socket

# get name of HTTP server
SERVER_ADDRESS = "www.pythoninstitute.org"

# create socket
socket_ = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

# the target address format is specfici to INET format
socket_.connect((SERVER_ADDRESS, 80))
request = f"""GET / HTTP/1.1\r\nHost: {SERVER_ADDRESS}\r\nConnection: close\r\n\r\n"""
socket_.send(bytes(request, "utf8"))
reply = socket_.recv(1000)
print(reply)

# connect socket

# send request

# close connection
# Out:
# b'HTTP/1.1 301 Moved Permanently\r\nServer: nginx/1.18.0 (Ubuntu)\r\nDate: Sat, 07 Jan 2023 11:41:16 GMT\r\nContent-Type: text/html\r\nContent-Length: 178\r\nConnection: close\r\nLocation: https://pythoninstitute.org/\r\n\r\n<html>\r\n<head><title>301 Moved Permanently</title></head>\r\n<body>\r\n<center><h1>301 Moved Permanently</h1></center>\r\n<hr><center>nginx/1.18.0 (Ubuntu)</center>\r\n</body>\r\n</html>\r\n'

# %%
import socket


server_addr = "www.facebook.com"
sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
sock.connect((server_addr, 80))
sock.send(b"GET / HTTP/1.1\r\nHost: " +
          bytes(server_addr, "utf8") +
          b"\r\nConnection: close\r\n\r\n")
reply = sock.recv(1000)
print(reply)
sock.shutdown(socket.SHUT_RDWR)
sock.close()
print()
reply
# Out:
# b'HTTP/1.1 301 Moved Permanently\r\nLocation: https://www.facebook.com/\r\nContent-Type: text/plain\r\nServer: proxygen-bolt\r\nDate: Sat, 07 Jan 2023 12:44:58 GMT\r\nConnection: close\r\nContent-Length: 0\r\n\r\n'
# b'HTTP/1.1 301 Moved Permanently\r\nLocation: https://www.facebook.com/\r\nContent-Type: text/plain\r\nServer: proxygen-bolt\r\nDate: Sat, 07 Jan 2023 12:44:58 GMT\r\nConnection: close\r\nContent-Length: 0\r\n\r\n'

# %%
import socket

ADDRESS:str = "www.google.com"
PORT:int = 80
target = (ADDRESS, PORT)

# Create socket.
client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
# Connect to target.
client_socket.connect(target)

# Define message to send to server.
request = "GET / HTTP/1.1\r\n"
header1 = f"Host: {ADDRESS}\r\n"
header2 = "Connection: close\r\n"
endline = "\r\n"
message = request + header1 + header2 + endline
client_socket.send(message.encode())
while content := client_socket.recv(100):
    print("LINE: " + str(content))
client_socket.shutdown(socket.SHUT_RDWR)
client_socket.close()
client_socket
# Out:
# LINE: b'HTTP/1.1 200 OK\r\nDate: Sun, 08 Jan 2023 12:24:14 GMT\r\nExpires: -1\r\nCache-Control: private, max-age=0'
# LINE: b'\r\nContent-Type: text/html; charset=ISO-8859-1\r\nCross-Origin-Opener-Policy: same-origin-allow-popups;'
# LINE: b' report-to="gws"\r\nReport-To: {"group":"gws","max_age":2592000,"endpoints":[{"url":"https://csp.withg'
# LINE: b'oogle.com/csp/report-to/gws/other"}]}\r\nP3P: CP="This is not a P3P policy! See g.co/p3phelp for more '
# LINE: b'info."\r\nServer: gws\r\nX-XSS-Protection: 0\r\nX-Frame-Options: SAMEORIGIN\r\nSet-Cookie: 1P_JAR=2023-01-08'
# LINE: b'-12; expires=Tue, 07-Feb-2023 12:24:14 GMT; path=/; domain=.google.com; Secure\r\nSet-Cookie: AEC=ARSK'
# LINE: b'qsKX5kyr6RyP2TqqRWl4AadsTHnk2h0sAI1wJSi26hdQsG5lmgCqNw; expires=Fri, 07-Jul-2023 12:24:14 GMT; path='
# LINE: b'/; domain=.google.com; Secure; HttpOnly; SameSite=lax\r\nSet-Cookie: NID=511=sEeYObxlQ4yaorvxZcKf1SMwc'
# LINE: b'Q9Ihlj-6pGzS-LL6sCVNC88zcIEvzuXj61-zKXYzpWLqN0mqLvap5najjev8jSMUEsll_ZRrosJDvpYxZ0-wvckUWc6ipRQ_S1u-'
# LINE: b'llzEubqAR985zhFrOCQZ6QFC3tdRD5lMAlRbmseUWje1rg; expires=Mon, 10-Jul-2023 12:24:14 GMT; path=/; domai'
# LINE: b'n=.google.com; HttpOnly\r\nAccept-Ranges: none\r\nVary: Accept-Encoding\r\nConnection: close\r\nTransfer-Enc'
# LINE: b'oding: chunked\r\n\r\n5b3a\r\n<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang='
# LINE: b'"en-AU"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/ima'
# LINE: b'ges/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><scr'
# LINE: b'ipt nonce="-uf_P2wfcPOZsT_bJhByqA">(function(){window.google={kEI:\'7rW6Y7fZHLqx0PEPqoOj8As\',kEXPI:\'0'
# LINE: b',18168,1341241,6058,207,4804,2316,383,246,5,1129120,1197749,645,112,379985,16114,28684,22430,1362,12'
# LINE: b'320,17579,4998,13228,3847,10622,22741,5081,1593,1279,2742,149,561,542,840,6297,3514,606,2023,2299,14'
# LINE: b'668,3227,2845,7,5599,19390,4086,4695,1851,2614,13142,3,346,230,1014,1,5444,149,11323,2652,4,1528,230'
# LINE: b'4,27348,7422,7356,11443,2216,4437,14995,7615,2533,4094,4052,3,3541,1,11942,30212,2,14022,2715,23024,'
# LINE: b'5679,1021,2380,22667,6074,4568,6259,23418,1252,5835,14968,4332,7484,445,2,2,1,26632,8155,7381,2,1596'
# LINE: b'8,873,19633,7,1922,5784,3995,19130,1509,751,9932,4832,23188,3315,20137,14,82,3890,751,14886,679,1622'
# LINE: b',1778,3852,1125,8988,5903,1742,2355,2322,933,564,2,563,991,782,606,878,179,90,495,426,1034,42,291,26'
# LINE: b'69,723,926,1410,20,3,260,607,136,23,1951,150,290,135,1550,951,1013,1206,947,556,4,6,291,301,3136,227'
# LINE: b',1219,551,484,244,363,258,770,181,1481,1252,5,1519,129,109,68,395,57,160,85,8,20,210,22,103,131,315,'
# LINE: b'182,637,1229,120,840,62,1392,1238,1570,49,8,1065,77,565,36,12,105,959,296,117,536,383,503,495,555,11'
# LINE: b'99,933,334,1392,40,1080,651,45,212,2,218,19,118,20,111,65,1776,819,846,520,1975,414,932,5273792,165,'
# LINE: b'35,8798849,3311,940,2,19730,1,298,48,3658,30,20726812,3219984,2862027,1180116,1964,1007,15666,3405,5'
# LINE: b"595,11,3834,5676,1522,1479676',kBL:'5roH'};google.sn='webhp';google.kHL='en-AU';})();(function(){\nva"
# LINE: b'r f=this||self;var h,k=[];function l(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)'
# LINE: b'a=a.parentNode;return b||h}function m(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("lei'
# LINE: b'd")));)a=a.parentNode;return b}\nfunction n(a,b,c,d,g){var e="";c||-1!==b.search("&ei=")||(e="&ei="+l'
# LINE: b'(d),-1===b.search("&lei=")&&(d=m(d))&&(e+="&lei="+d));d="";!c&&f._cshid&&-1===b.search("&cshid=")&&"'
# LINE: b'slh"!==a&&(d="&cshid="+f._cshid);c=c||"/"+(g||"gen_204")+"?atyp=i&ct="+a+"&cad="+b+e+"&zx="+Date.now'
# LINE: b'()+d;/^http:/i.test(c)&&"https:"===window.location.protocol&&(google.ml&&google.ml(Error("a"),!1,{sr'
# LINE: b'c:c,glmm:1}),c="");return c};h=google.kEI;google.getEI=l;google.getLEI=m;google.ml=function(){return'
# LINE: b' null};google.log=function(a,b,c,d,g){if(c=n(a,b,c,d,g)){a=new Image;var e=k.length;k[e]=a;a.onerror'
# LINE: b'=a.onload=a.onabort=function(){delete k[e]};a.src=c}};google.logUrl=n;}).call(this);(function(){goog'
# LINE: b'le.y={};google.sy=[];google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c'
# LINE: b'])}google.y[c]=[a,b];return!1};google.sx=function(a){google.sy.push(a)};google.lm=[];google.plm=func'
# LINE: b'tion(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push(['
# LINE: b'[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};google.bx=!1;google.lx=function(){};}'
# LINE: b').call(this);google.f={};(function(){\ndocument.documentElement.addEventListener("submit",function(b)'
# LINE: b'{var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.val'
# LINE: b'ue?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEven'
# LINE: b'tListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElem'
# LINE: b'ent)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0'
# LINE: b');}).call(this);</script><style>#gb{font:13px/27px Arial,sans-serif;height:30px}#gbz,#gbg{position:a'
# LINE: b'bsolute;white-space:nowrap;top:0;height:30px;z-index:1000}#gbz{left:0;padding-left:4px}#gbg{right:0;'
# LINE: b'padding-right:5px}#gbs{background:transparent;position:absolute;top:-999px;visibility:hidden;z-index'
# LINE: b':998;right:0}.gbto #gbs{background:#fff}#gbx3,#gbx4{background-color:#2d2d2d;background-image:none;_'
# LINE: b'background-image:none;background-position:0 -138px;background-repeat:repeat-x;border-bottom:1px soli'
# LINE: b'd #000;font-size:24px;height:29px;_height:30px;opacity:1;filter:alpha(opacity=100);position:absolute'
# LINE: b';top:0;width:100%;z-index:990}#gbx3{left:0}#gbx4{right:0}#gbb{position:relative}#gbbw{left:0;positio'
# LINE: b'n:absolute;top:30px;width:100%}.gbtcb{position:absolute;visibility:hidden}#gbz .gbtcb{right:0}#gbg .'
# LINE: b'gbtcb{left:0}.gbxx{display:none !important}.gbxo{opacity:0 !important;filter:alpha(opacity=0) !impor'
# LINE: b'tant}.gbm{position:absolute;z-index:999;top:-999px;visibility:hidden;text-align:left;border:1px soli'
# LINE: b'd #bebebe;background:#fff;-moz-box-shadow:-1px 1px 1px rgba(0,0,0,.2);-webkit-box-shadow:0 2px 4px r'
# LINE: b'gba(0,0,0,.2);box-shadow:0 2px 4px rgba(0,0,0,.2)}.gbrtl .gbm{-moz-box-shadow:1px 1px 1px rgba(0,0,0'
# LINE: b',.2)}.gbto .gbm,.gbto #gbs{top:29px;visibility:visible}#gbz .gbm{left:0}#gbg .gbm{right:0}.gbxms{bac'
# LINE: b'kground-color:#ccc;display:block;position:absolute;z-index:1;top:-1px;left:-2px;right:-2px;bottom:-2'
# LINE: b'px;opacity:.4;-moz-border-radius:3px;filter:progid:DXImageTransform.Microsoft.Blur(pixelradius=5);*o'
# LINE: b'pacity:1;*top:-2px;*left:-5px;*right:5px;*bottom:4px;-ms-filter:"progid:DXImageTransform.Microsoft.B'
# LINE: b'lur(pixelradius=5)";opacity:1\\0/;top:-4px\\0/;left:-6px\\0/;right:5px\\0/;bottom:4px\\0/}.gbma{position:'
# LINE: b'relative;top:-1px;border-style:solid dashed dashed;border-color:transparent;border-top-color:#c0c0c0'
# LINE: b';display:-moz-inline-box;display:inline-block;font-size:0;height:0;line-height:0;width:0;border-widt'
# LINE: b'h:3px 3px 0;padding-top:1px;left:4px}#gbztms1,#gbi4m1,#gbi4s,#gbi4t{zoom:1}.gbtc,.gbmc,.gbmcc{displa'
# LINE: b'y:block;list-style:none;margin:0;padding:0}.gbmc{background:#fff;padding:10px 0;position:relative;z-'
# LINE: b'index:2;zoom:1}.gbt{position:relative;display:-moz-inline-box;display:inline-block;line-height:27px;'
# LINE: b'padding:0;vertical-align:top}.gbt{*display:inline}.gbto{box-shadow:0 2px 4px rgba(0,0,0,.2);-moz-box'
# LINE: b'-shadow:0 2px 4px rgba(0,0,0,.2);-webkit-box-shadow:0 2px 4px rgba(0,0,0,.2)}.gbzt,.gbgt{cursor:poin'
# LINE: b'ter;display:block;text-decoration:none !important}span#gbg6,span#gbg4{cursor:default}.gbts{border-le'
# LINE: b'ft:1px solid transparent;border-right:1px solid transparent;display:block;*display:inline-block;padd'
# LINE: b'ing:0 5px;position:relative;z-index:1000}.gbts{*display:inline}.gbzt .gbts{display:inline;zoom:1}.gb'
# LINE: b'to .gbts{background:#fff;border-color:#bebebe;color:#36c;padding-bottom:1px;padding-top:2px}.gbz0l .'
# LINE: b'gbts{color:#fff;font-weight:bold}.gbtsa{padding-right:9px}#gbz .gbzt,#gbz .gbgt,#gbg .gbgt{color:#cc'
# LINE: b'c!important}.gbtb2{display:block;border-top:2px solid transparent}.gbto .gbzt .gbtb2,.gbto .gbgt .gb'
# LINE: b'tb2{border-top-width:0}.gbtb .gbts{background:url(https://ssl.gstatic.com/gb/images/b_8d5afc09.png);'
# LINE: b'_background:url(https://ssl.gstatic.com/gb/images/b8_3615d64d.png);background-position:-27px -22px;b'
# LINE: b'order:0;font-size:0;padding:29px 0 0;*padding:27px 0 0;width:1px}.gbzt:hover,.gbzt:focus,.gbgt-hvr,.'
# LINE: b'gbgt:focus{background-color:#4c4c4c;background-image:none;_background-image:none;background-position'
# LINE: b':0 -102px;background-repeat:repeat-x;outline:none;text-decoration:none !important}.gbpdjs .gbto .gbm'
# LINE: b'{min-width:99%}.gbz0l .gbtb2{border-top-color:#dd4b39!important}#gbi4s,#gbi4s1{font-weight:bold}#gbg'
# LINE: b'6.gbgt-hvr,#gbg6.gbgt:focus{background-color:transparent;background-image:none}.gbg4a{font-size:0;li'
# LINE: b'ne-height:0}.gbg4a .gbts{padding:27px 5px 0;*padding:25px 5px 0}.gbto .gbg4a .gbts{padding:29px 5px '
# LINE: b'1px;*padding:27px 5px 1px}#gbi4i,#gbi4id{left:5px;border:0;height:24px;position:absolute;top:1px;wid'
# LINE: b'th:24px}.gbto #gbi4i,.gbto #gbi4id{top:3px}.gbi4p{display:block;width:24px}#gbi4id{background-positi'
# LINE: b'on:-44px -101px}#gbmpid{background-position:0 0}#gbmpi,#gbmpid{border:none;display:inline-block;heig'
# LINE: b'ht:48px;width:48px}#gbmpiw{display:inline-block;line-height:9px;padding-left:20px;margin-top:10px;po'
# LINE: b'sition:relative}#gbmpi,#gbmpid,#gbmpiw{*display:inline}#gbg5{font-size:0}#gbgs5{padding:5px !importa'
# LINE: b'nt}.gbto #gbgs5{padding:7px 5px 6px !important}#gbi5{background:url(https://ssl.gstatic.com/gb/image'
# LINE: b's/b_8d5afc09.png);_background:url(https://ssl.gstatic.com/gb/images/b8_3615d64d.png);background-posi'
# LINE: b'tion:0 0;display:block;font-size:0;height:17px;width:16px}.gbto #gbi5{background-position:-6px -22px'
# LINE: b'}.gbn .gbmt,.gbn .gbmt:visited,.gbnd .gbmt,.gbnd .gbmt:visited{color:#dd8e27 !important}.gbf .gbmt,.'
# LINE: b'gbf .gbmt:visited{color:#900 !important}.gbmt,.gbml1,.gbmlb,.gbmt:visited,.gbml1:visited,.gbmlb:visi'
# LINE: b'ted{color:#36c !important;text-decoration:none !important}.gbmt,.gbmt:visited{display:block}.gbml1,.'
# LINE: b'gbmlb,.gbml1:visited,.gbmlb:visited{display:inline-block;margin:0 10px}.gbml1,.gbmlb,.gbml1:visited,'
# LINE: b'.gbmlb:visited{*display:inline}.gbml1,.gbml1:visited{padding:0 10px}.gbml1-hvr,.gbml1:focus{outline:'
# LINE: b'none;text-decoration:underline !important}#gbpm .gbml1{display:inline;margin:0;padding:0;white-space'
# LINE: b':nowrap}.gbmlb,.gbmlb:visited{line-height:27px}.gbmlb-hvr,.gbmlb:focus{outline:none;text-decoration:'
# LINE: b'underline !important}.gbmlbw{color:#ccc;margin:0 10px}.gbmt{padding:0 20px}.gbmt:hover,.gbmt:focus{b'
# LINE: b'ackground:#eee;cursor:pointer;outline:0 solid black;text-decoration:none !important}.gbm0l,.gbm0l:vi'
# LINE: b'sited{color:#000 !important;font-weight:bold}.gbmh{border-top:1px solid #bebebe;font-size:0;margin:1'
# LINE: b'0px 0}#gbd4 .gbmc{background:#f5f5f5;padding-top:0}#gbd4 .gbsbic::-webkit-scrollbar-track:vertical{b'
# LINE: b'ackground-color:#f5f5f5;margin-top:2px}#gbmpdv{background:#fff;border-bottom:1px solid #bebebe;-moz-'
# LINE: b'box-shadow:0 2px 4px rgba(0,0,0,.12);-o-box-shadow:0 2px 4px rgba(0,0,0,.12);-webkit-box-shadow:0 2p'
# LINE: b'x 4px rgba(0,0,0,.12);box-shadow:0 2px 4px rgba(0,0,0,.12);position:relative;z-index:1}#gbd4 .gbmh{m'
# LINE: b'argin:0}.gbmtc{padding:0;margin:0;line-height:27px}.GBMCC:last-child:after,#GBMPAL:last-child:after{'
# LINE: b"content:'\\0A\\0A';white-space:pre;position:absolute}#gbmps{*zoom:1}#gbd4 .gbpc,#gbmpas .gbmt{line-hei"
# LINE: b'ght:17px}#gbd4 .gbpgs .gbmtc{line-height:27px}#gbd4 .gbmtc{border-bottom:1px solid #bebebe}#gbd4 .gb'
# LINE: b'pc{display:inline-block;margin:16px 0 10px;padding-right:50px;vertical-align:top}#gbd4 .gbpc{*displa'
# LINE: b'y:inline}.gbpc .gbps,.gbpc .gbps2{display:block;margin:0 20px}#gbmplp.gbps{margin:0 10px}.gbpc .gbps'
# LINE: b'{color:#000;font-weight:bold}.gbpc .gbpd{margin-bottom:5px}.gbpd .gbmt,.gbpd .gbps{color:#666 !impor'
# LINE: b'tant}.gbpd .gbmt{opacity:.4;filter:alpha(opacity=40)}.gbps2{color:#666;display:block}.gbp0{display:n'
# LINE: b'one}.gbp0 .gbps2{font-weight:bold}#gbd4 .gbmcc{margin-top:5px}.gbpmc{background:#fef9db}.gbpmc .gbpm'
# LINE: b'tc{padding:10px 20px}#gbpm{border:0;*border-collapse:collapse;border-spacing:0;margin:0;white-space:'
# LINE: b'normal}#gbpm .gbpmtc{border-top:none;color:#000 !important;font:11px Arial,sans-serif}#gbpms{*white-'
# LINE: b'space:nowrap}.gbpms2{font-weight:bold;white-space:nowrap}#gbmpal{*border-collapse:collapse;border-sp'
# LINE: b'acing:0;border:0;margin:0;white-space:nowrap;width:100%}.gbmpala,.gbmpalb{font:13px Arial,sans-serif'
# LINE: b';line-height:27px;padding:10px 20px 0;white-space:nowrap}.gbmpala{padding-left:0;text-align:left}.gb'
# LINE: b'mpalb{padding-right:0;text-align:right}#gbmpasb .gbps{color:#000}#gbmpal .gbqfbb{margin:0 20px}.gbp0'
# LINE: b' .gbps{*display:inline}a.gbiba{margin:8px 20px 10px}.gbmpiaw{display:inline-block;padding-right:10px'
# LINE: b';margin-bottom:6px;margin-top:10px}.gbxv{visibility:hidden}.gbmpiaa{display:block;margin-top:10px}.g'
# LINE: b'bmpia{border:none;display:block;height:48px;width:48px}.gbmpnw{display:inline-block;height:auto;marg'
# LINE: b'in:10px 0;vertical-align:top}\n.gbqfb,.gbqfba,.gbqfbb{-moz-border-radius:2px;-webkit-border-radius:2p'
# LINE: b'x;border-radius:2px;cursor:default !important;display:inline-block;font-weight:bold;height:29px;line'
# LINE: b'-height:29px;min-width:54px;*min-width:70px;padding:0 8px;text-align:center;text-decoration:none !im'
# LINE: b'portant;-moz-user-select:none;-webkit-user-select:none}.gbqfb:focus,.gbqfba:focus,.gbqfbb:focus{bord'
# LINE: b'er:1px s'
# LINE: b'olid #4d90fe;-moz-box-shadow:inset 0 0 0 1px rgba(255, 255, 255, 0.5);-webkit-box-shadow:inset 0 0 0'
# LINE: b' 1px rgba(255, 255, 255, 0.5);box-shadow:inset 0 0 0 1px rgba(255, 255, 255, 0.5);outline:none}.gbqf'
# LINE: b'b-hvr:focus,.gbqfba-hvr:focus,.gbqfbb-hvr:focus{-webkit-box-shadow:inset 0 0 0 1px #fff,0 1px 1px rg'
# LINE: b'ba(0,0,0,.1);-moz-box-shadow:inset 0 0 0 1px #fff,0 1px 1px rgba(0,0,0,.1);box-shadow:inset 0 0 0 1p'
# LINE: b'x #fff,0 1px 1px rgba(0,0,0,.1)}.gbqfb-no-focus:focus{border:1px solid #3079ed;-moz-box-shadow:none;'
# LINE: b'-webkit-box-shadow:none;box-shadow:none}.gbqfb-hvr,.gbqfba-hvr,.gbqfbb-hvr{-webkit-box-shadow:0 1px '
# LINE: b'1px rgba(0,0,0,.1);-moz-box-shadow:0 1px 1px rgba(0,0,0,.1);box-shadow:0 1px 1px rgba(0,0,0,.1)}.gbq'
# LINE: b'fb::-moz-focus-inner,.gbqfba::-moz-focus-inner,.gbqfbb::-moz-focus-inner{border:0}.gbqfba,.gbqfbb{bo'
# LINE: b'rder:1px solid #dcdcdc;border-color:rgba(0,0,0,.1);color:#444 !important;font-size:11px}.gbqfb{backg'
# LINE: b'round-color:#4d90fe;background-image:-webkit-gradient(linear,left top,left bottom,from(#4d90fe),to(#'
# LINE: b'4787ed));background-image:-webkit-linear-gradient(top,#4d90fe,#4787ed);background-image:-moz-linear-'
# LINE: b'gradient(top,#4d90fe,#4787ed);background-image:-ms-linear-gradient(top,#4d90fe,#4787ed);background-i'
# LINE: b'mage:-o-linear-gradient(top,#4d90fe,#4787ed);background-image:linear-gradient(top,#4d90fe,#4787ed);f'
# LINE: b"ilter:progid:DXImageTransform.Microsoft.gradient(startColorStr='#4d90fe',EndColorStr='#4787ed');bord"
# LINE: b'er:1px solid #3079ed;color:#fff!important;margin:0 0}.gbqfb-hvr{border-color:#2f5bb7}.gbqfb-hvr:focu'
# LINE: b's{border-color:#2f5bb7}.gbqfb-hvr,.gbqfb-hvr:focus{background-color:#357ae8;background-image:-webkit'
# LINE: b'-gradient(linear,left top,left bottom,from(#4d90fe),to(#357ae8));background-image:-webkit-linear-gra'
# LINE: b'dient(top,#4d90fe,#357ae8);background-image:-moz-linear-gradient(top,#4d90fe,#357ae8);background-ima'
# LINE: b'ge:-ms-linear-gradient(top,#4d90fe,#357ae8);background-image:-o-linear-gradient(top,#4d90fe,#357ae8)'
# LINE: b';background-image:linear-gradient(top,#4d90fe,#357ae8)}.gbqfb:active{background-color:inherit;-webki'
# LINE: b't-box-shadow:inset 0 1px 2px rgba(0, 0, 0, 0.3);-moz-box-shadow:inset 0 1px 2px rgba(0, 0, 0, 0.3);b'
# LINE: b'ox-shadow:inset 0 1px 2px rgba(0, 0, 0, 0.3)}.gbqfba{background-color:#f5f5f5;background-image:-webk'
# LINE: b'it-gradient(linear,left top,left bottom,from(#f5f5f5),to(#f1f1f1));background-image:-webkit-linear-g'
# LINE: b'radient(top,#f5f5f5,#f1f1f1);background-image:-moz-linear-gradient(top,#f5f5f5,#f1f1f1);background-i'
# LINE: b'mage:-ms-linear-gradient(top,#f5f5f5,#f1f1f1);background-image:-o-linear-gradient(top,#f5f5f5,#f1f1f'
# LINE: b'1);background-image:linear-gradient(top,#f5f5f5,#f1f1f1);filter:progid:DXImageTransform.Microsoft.gr'
# LINE: b"adient(startColorStr='#f5f5f5',EndColorStr='#f1f1f1')}.gbqfba-hvr,.gbqfba-hvr:active{background-colo"
# LINE: b'r:#f8f8f8;background-image:-webkit-gradient(linear,left top,left bottom,from(#f8f8f8),to(#f1f1f1));b'
# LINE: b'ackground-image:-webkit-linear-gradient(top,#f8f8f8,#f1f1f1);background-image:-moz-linear-gradient(t'
# LINE: b'op,#f8f8f8,#f1f1f1);background-image:-ms-linear-gradient(top,#f8f8f8,#f1f1f1);background-image:-o-li'
# LINE: b'near-gradient(top,#f8f8f8,#f1f1f1);background-image:linear-gradient(top,#f8f8f8,#f1f1f1);filter:prog'
# LINE: b"id:DXImageTransform.Microsoft.gradient(startColorStr='#f8f8f8',EndColorStr='#f1f1f1')}.gbqfbb{backgr"
# LINE: b'ound-color:#fff;background-image:-webkit-gradient(linear,left top,left bottom,from(#fff),to(#fbfbfb)'
# LINE: b');background-image:-webkit-linear-gradient(top,#fff,#fbfbfb);background-image:-moz-linear-gradient(t'
# LINE: b'op,#fff,#fbfbfb);background-image:-ms-linear-gradient(top,#fff,#fbfbfb);background-image:-o-linear-g'
# LINE: b'radient(top,#fff,#fbfbfb);background-image:linear-gradient(top,#fff,#fbfbfb);filter:progid:DXImageTr'
# LINE: b"ansform.Microsoft.gradient(startColorStr='#ffffff',EndColorStr='#fbfbfb')}.gbqfbb-hvr,.gbqfbb-hvr:ac"
# LINE: b'tive{background-color:#fff;background-image:-webkit-gradient(linear,left top,left bottom,from(#fff),'
# LINE: b'to(#f8f8f8));background-image:-webkit-linear-gradient(top,#fff,#f8f8f8);background-image:-moz-linear'
# LINE: b'-gradient(top,#fff,#f8f8f8);background-image:-ms-linear-gradient(top,#fff,#f8f8f8);background-image:'
# LINE: b'-o-linear-gradient(top,#fff,#f8f8f8);background-image:linear-gradient(top,#fff,#f8f8f8);filter:progi'
# LINE: b"d:DXImageTransform.Microsoft.gradient(startColorStr='#ffffff',EndColorStr='#f8f8f8')}.gbqfba-hvr,.gb"
# LINE: b'qfba-hvr:active,.gbqfbb-hvr,.gbqfbb-hvr:active{border-color:#c6c6c6;-webkit-box-shadow:0 1px 1px rgb'
# LINE: b'a(0,0,0,.1);-moz-box-shadow:0 1px 1px rgba(0,0,0,.1);box-shadow:0 1px 1px rgba(0,0,0,.1);color:#222 '
# LINE: b'!important}.gbqfba:active,.gbqfbb:active{-webkit-box-shadow:inset 0 1px 2px rgba(0,0,0,.1);-moz-box-'
# LINE: b'shadow:inset 0 1px 2px rgba(0,0,0,.1);box-shadow:inset 0 1px 2px rgba(0,0,0,.1)}\n.gbprcd{padding:0;w'
# LINE: b'idth:258px;white-space:normal}.gbprcb{display:inline-block;height:27px;padding:0 15px;text-decoratio'
# LINE: b'n:none}#gbprc .gbprcbc{background-color:;background-image:none;border-color:;color:!important}#gbprc'
# LINE: b' .gbprcbc:hover{color:!important}#gbprc .gbprcbc:active,#gbprc .gbprcbc:focus{color:!important}.gbpr'
# LINE: b'ct{color:#666;line-height:17px;margin:0;margin-bottom:20px}.gbprci{color:#333;font-size:16px;line-he'
# LINE: b'ight:20px;margin:0;margin-bottom:16px}#gbprc .gbmc{padding:26px;padding-bottom:22px;border:1px solid'
# LINE: b' #bebebe}#gbprc .gbm{border:0}#gbprc .gbprcx,#gbprc .gbprcx.gbgt-hvr,#gbprc .gbprcx:focus,#gbprc .gb'
# LINE: b'prcx:active{right:12px;background:url(//ssl.gstatic.com/s2/oz/images/stars/x.png);display:block;heig'
# LINE: b'ht:9px;opacity:.8;filter:alpha(opacity=80);position:absolute;top:12px;width:9px}#gbprc .gbprcx.gbgt-'
# LINE: b'hvr,#gbprc .gbprcx:focus,#gbprc .gbprcx:active{opacity:1;filter:alpha(opacity=100)}.gbgs .gbmab,.gbg'
# LINE: b's .gbmab{left:10px;margin:40px 0 0}.gbgs .gbmac,.gbgs .gbmac{left:10px;margin:41px 0 0}.gbemi .gbgs '
# LINE: b'.gbmab,.gbem .gbgs .gbmab{left:10px;margin:40px 0 0}.gbemi .gbgs .gbmac,.gbem .gbgs .gbmac{left:10px'
# LINE: b';margin:41px 0 0}.gbesi .gbgs .gbmab,.gbes .gbgs .gbmab{left:10px;margin:40px 0 0}.gbesi .gbgs .gbma'
# LINE: b'c,.gbes .gbgs .gbmac{left:10px;margin:41px 0 0}#gbprca .gbmab{z-index:999}#gbprca .gbmac{border-bott'
# LINE: b'om-color:#fff;z-index:999}#gbprcs{position:absolute;background:transparent;top:-999px;z-index:-1;vis'
# LINE: b'ibility:hidden;margin-top:1px;margin-left:1px}\n#gb #gbprc{right:-28px;top:15px;z-index:997}#gbprca{l'
# LINE: b'eft:-63px;position:relative;top:-22px}.gbmab,.gbmac{left:5px;border-style:dashed dashed solid;border'
# LINE: b'-color:transparent;border-bottom-color:#bebebe;border-width:0 10px 10px;display:-moz-inline-box;disp'
# LINE: b'lay:inline-block;font-size:0;height:0;line-height:0;position:absolute;top:0;width:0;z-index:1000}.gb'
# LINE: b'mab,.gbmac{visibility:hidden}.gbmac{border-bottom-color:#fff}.gbto .gbmab,.gbto .gbmac{visibility:vi'
# LINE: b'sible}#gbqfqw,#gbqfb{vertical-align:top}#gbqfbw{right:0;margin:0 15px;position:absolute;top:0}.gbqfb'
# LINE: b'{background-color:#4d90fe;background-image:-webkit-gradient(linear,left top,left bottom,from(#4d90fe'
# LINE: b'),to(#4787ed));background-image:-webkit-linear-gradient(top,#4d90fe,#4787ed);background-image:-moz-l'
# LINE: b'inear-gradient(top,#4d90fe,#4787ed);background-image:-ms-linear-gradient(top,#4d90fe,#4787ed);backgr'
# LINE: b'ound-image:-o-linear-gradient(top,#4d90fe,#4787ed);background-image:linear-gradient(top,#4d90fe,#478'
# LINE: b'7ed);filter:progid:DXImageTransform.Microsoft.gradient(start'
# LINE: b"ColorStr='#4d90fe',EndColorStr='#4787ed');border:1px solid #3079ed;-moz-border-radius:2px;-webkit-bo"
# LINE: b'rder-radius:2px;border-radius:2px;-moz-user-select:none;-webkit-user-select:none;color:#fff;cursor:d'
# LINE: b'efault;font-size:11px;font-weight:bold;height:29px;min-width:54px;*min-width:70px;text-align:center;'
# LINE: b'padding:0 8px}.gbqfb-hvr{border:1px solid #2f5bb7;background-color:#357ae8;background-image:-webkit-'
# LINE: b'gradient(linear,left top,left bottom,from(#4d90fe),to(#357ae8));background-image:-webkit-linear-grad'
# LINE: b'ient(top,#4d90fe,#357ae8);background-image:-moz-linear-gradient(top,#4d90fe,#357ae8);background-imag'
# LINE: b'e:-ms-linear-gradient(top,#4d90fe,#357ae8);background-image:-o-linear-gradient(top,#4d90fe,#357ae8);'
# LINE: b'background-image:linear-gradient(top,#4d90fe,#357ae8);-webkit-box-shadow:0 1px 1px rgba(0,0,0,.1);-m'
# LINE: b'oz-box-shadow:0 1px 1px rgba(0,0,0,.1);box-shadow:0 1px 1px rgba(0,0,0,.1)}.gbqfb:focus{-moz-box-sha'
# LINE: b'dow:inset 0 0 0 1px #fff;-webkit-box-shadow:inset 0 0 0 1px #fff;box-shadow:inset 0 0 0 1px #fff;out'
# LINE: b'line:none}.gbqfb::-moz-focus-inner{border:0}.gbqfb-hvr:focus{-moz-box-shadow:inset 0 0 0 1px #fff,0 '
# LINE: b'1px 1px rgba(0,0,0,.1);-webkit-box-shadow:inset 0 0 0 1px #fff,0 1px 1px rgba(0,0,0,.1);box-shadow:i'
# LINE: b'nset 0 0 0 1px #fff,0 1px 1px rgba(0,0,0,.1)}.gbqfb:active{-moz-box-shadow:inset 0 1px 2px rgba(0,0,'
# LINE: b'0,.3);-webkit-box-shadow:inset 0 1px 2px rgba(0,0,0,.3);box-shadow:inset 0 1px 2px rgba(0,0,0,.3)}\n#'
# LINE: b'gbmpas{max-height:220px}#gbmm{max-height:530px}.gbsb{-webkit-box-sizing:border-box;display:block;pos'
# LINE: b'ition:relative;*zoom:1}.gbsbic{overflow:auto}.gbsbis .gbsbt,.gbsbis .gbsbb{-webkit-mask-box-image:-w'
# LINE: b'ebkit-gradient(linear,left top,right top,color-stop(0,rgba(0,0,0,.1)),color-stop(.5,rgba(0,0,0,.8)),'
# LINE: b'color-stop(1,rgba(0,0,0,.1)));left:0;margin-right:0;opacity:0;position:absolute;width:100%}.gbsb .gb'
# LINE: b'sbt:after,.gbsb .gbsbb:after{content:"";display:block;height:0;left:0;position:absolute;width:100%}.'
# LINE: b'gbsbis .gbsbt{background:-webkit-gradient(linear,left top,left bottom,from(rgba(0,0,0,.2)),to(rgba(0'
# LINE: b',0,0,0)));background-image:-webkit-linear-gradient(top,rgba(0,0,0,.2),rgba(0,0,0,0));background-imag'
# LINE: b'e:-moz-linear-gradient(top,rgba(0,0,0,.2),rgba(0,0,0,0));background-image:-ms-linear-gradient(top,rg'
# LINE: b'ba(0,0,0,.2),rgba(0,0,0,0));background-image:-o-linear-gradient(top,rgba(0,0,0,.2),rgba(0,0,0,0));ba'
# LINE: b'ckground-image:linear-gradient(top,rgba(0,0,0,.2),rgba(0,0,0,0));height:6px;top:0}.gbsb .gbsbt:after'
# LINE: b'{border-top:1px solid #ebebeb;border-color:rgba(0,0,0,.3);top:0}.gbsb .gbsbb{-webkit-mask-box-image:'
# LINE: b'-webkit-gradient(linear,left top,right top,color-stop(0,rgba(0,0,0,.1)),color-stop(.5,rgba(0,0,0,.8)'
# LINE: b'),color-stop(1,rgba(0,0,0,.1)));background:-webkit-gradient(linear,left bottom,left top,from(rgba(0,'
# LINE: b'0,0,.2)),to(rgba(0,0,0,0)));background-image:-webkit-linear-gradient(bottom,rgba(0,0,0,.2),rgba(0,0,'
# LINE: b'0,0));background-image:-moz-linear-gradient(bottom,rgba(0,0,0,.2),rgba(0,0,0,0));background-image:-m'
# LINE: b's-linear-gradient(bottom,rgba(0,0,0,.2),rgba(0,0,0,0));background-image:-o-linear-gradient(bottom,rg'
# LINE: b'ba(0,0,0,.2),rgba(0,0,0,0));background-image:linear-gradient(bottom,rgba(0,0,0,.2),rgba(0,0,0,0));bo'
# LINE: b'ttom:0;height:4px}.gbsb .gbsbb:after{border-bottom:1px solid #ebebeb;border-color:rgba(0,0,0,.3);bot'
# LINE: b'tom:0}\n</style><style>body,td,a,p,.h{font-family:arial,sans-serif}body{margin:0;overflow-y:scroll}#g'
# LINE: b'og{padding:3px 8px 0}td{line-height:.8em}.gac_m td{line-height:17px}form{margin-bottom:20px}.h{color'
# LINE: b':#1558d6}em{font-weight:bold;font-style:normal}.lst{height:25px;width:496px}.gsfi,.lst{font:18px ari'
# LINE: b'al,sans-serif}.gsfs{font:17px arial,sans-serif}.ds{display:inline-box;display:inline-block;margin:3p'
# LINE: b'x 0 4px;margin-left:4px}input{font-family:inherit}body{background:#fff;color:#000}a{color:#4b11a8;te'
# LINE: b'xt-decoration:none}a:hover,a:active{text-decoration:underline}.fl a{color:#1558d6}a:visited{color:#4'
# LINE: b'b11a8}.sblc{padding-top:5px}.sblc a{display:block;margin:2px 0;margin-left:13px;font-size:11px}.lsbb'
# LINE: b'{background:#f8f9fa;border:solid 1px;border-color:#dadce0 #70757a #70757a #dadce0;height:30px}.lsbb{'
# LINE: b'display:block}#WqQANb a{display:inline-block;margin:0 12px}.lsb{background:url(/images/nav_logo229.p'
# LINE: b'ng) 0 -261px repeat-x;border:none;color:#000;cursor:pointer;height:30px;margin:0;outline:0;font:15px'
# LINE: b' arial,sans-serif;vertical-align:top}.lsb:active{background:#dadce0}.lst:focus{outline:none}</style>'
# LINE: b'<script nonce="-uf_P2wfcPOZsT_bJhByqA">(function(){window.google.erd={jsr:1,bv:1719,de:true};\nvar h='
# LINE: b'this||self;var k,l=null!=(k=h.mei)?k:1,n,p=null!=(n=h.sdo)?n:!0,q=0,r,t=google.erd,v=t.jsr;google.ml'
# LINE: b'=function(a,b,d,m,e){e=void 0===e?2:e;b&&(r=a&&a.message);if(google.dl)return google.dl(a,e,d),null;'
# LINE: b'if(0>v){window.console&&console.error(a,d);if(-2===v)throw a;b=!1}else b=!a||!a.message||"Error load'
# LINE: b'ing script\r\ncd\r\n"===a.message||q>=l&&!m?!1:!0;if(!b)return null;q++;d=d||{};b=encodeURIComponent;var'
# LINE: b' c="/gen_204?atyp=i&ei="+b(google.kEI);google.kEXPI&&(c+="&jexpid="+b(google.kEXPI));c+="&srcpg="+b('
# LINE: b'google.sn)+"&jsr="+b(\r\n'
# LINE: b'6f32\r\nt.jsr)+"&bver="+b(t.bv);var f=a.lineNumber;void 0!==f&&(c+="&line="+f);var g=\na.fileName;g&&(0'
# LINE: b'<g.indexOf("-extension:/")&&(e=3),c+="&script="+b(g),f&&g===window.location.href&&(f=document.docume'
# LINE: b'ntElement.outerHTML.split("\\n")[f],c+="&cad="+b(f?f.substring(0,300):"No script found.")));c+="&jsel'
# LINE: b'="+e;for(var u in d)c+="&",c+=b(u),c+="=",c+=b(d[u]);c=c+"&emsg="+b(a.name+": "+a.message);c=c+"&jss'
# LINE: b't="+b(a.stack||"N/A");12288<=c.length&&(c=c.substr(0,12288));a=c;m||google.log(0,"",a);return a};win'
# LINE: b'dow.onerror=function(a,b,d,m,e){r!==a&&(a=e instanceof Error?e:Error(a),void 0===d||"lineNumber"in a'
# LINE: b'||(a.lineNumber=d),void 0===b||"fileName"in a||(a.fileName=b),google.ml(a,!1,void 0,!1,"SyntaxError"'
# LINE: b'===a.name||"SyntaxError"===a.message.substring(0,11)||-1!==a.message.indexOf("Script error")?3:0));r'
# LINE: b'=null;p&&q>=l&&(window.onerror=null)};})();(function(){try{/*\n\n Copyright The Closure Library Author'
# LINE: b's.\n SPDX-License-Identifier: Apache-2.0\n*/\nvar e=this||self;var aa=function(a,b,c,d){d=d||{};d._sn=['
# LINE: b'"cfg",b,c].join(".");window.gbar.logger.ml(a,d)};var g=window.gbar=window.gbar||{},h=window.gbar.i=w'
# LINE: b'indow.gbar.i||{},ba;function _tvn(a,b){a=parseInt(a,10);return isNaN(a)?b:a}function _tvf(a,b){a=par'
# LINE: b'seFloat(a);return isNaN(a)?b:a}function _tvv(a){return!!a}function p(a,b,c){(c||g)[a]=b}g.bv={n:_tvn'
# LINE: b'("2",0),r:"",f:".66.",e:"",m:_tvn("1",1)};\nfunction ca(a,b,c){var d="on"+b;if(a.addEventListener)a.a'
# LINE: b'ddEventListener(b,c,!1);else if(a.attachEvent)a.attachEvent(d,c);else{var f=a[d];a[d]=function(){var'
# LINE: b' k=f.apply(this,arguments),l=c.apply(this,arguments);return void 0==k?l:void 0==l?k:l&&k}}}var da=fu'
# LINE: b'nction(a){return function(){return g.bv.m==a}},ea=da(1),fa=da(2);p("sb",ea);p("kn",fa);h.a=_tvv;h.b='
# LINE: b'_tvf;h.c=_tvn;h.i=aa;var r=window.gbar.i.i;var t=function(){},u=function(){},ja=function(a){var b=ne'
# LINE: b'w Image,c=ha;b.onerror=b.onload=b.onabort=function(){try{delete ia[c]}catch(d){}};ia[c]=b;b.src=a;ha'
# LINE: b'=c+1},ia=[],ha=0;p("logger",{il:u,ml:t,log:ja});var v=window.gbar.logger;var w={},ka={},x=[],la=h.b('
# LINE: b'"0.1",.1),ma=h.a("1",!0),na=function(a,b){x.push([a,b])},oa=function(a,b){w[a]=b},pa=function(a){ret'
# LINE: b'urn a in w},A={},B=function(a,b){A[a]||(A[a]=[]);A[a].push(b)},C=function(a){B("m",a)},qa=function(a'
# LINE: b',b){var c=document.createElement("script");c.src=a;c.async=ma;Math.random()<la&&(c.onerror=function('
# LINE: b'){c.onerror=null;t(Error("Bundle load failed: name="+(b||"UNK")+" url="+a))});(document.getElementBy'
# LINE: b'Id("xjsc")||document.getElementsByTagName("body")[0]||\ndocument.getElementsByTagName("head")[0]).app'
# LINE: b'endChild(c)},sa=function(a){for(var b,c=0;(b=x[c])&&b[0]!=a;++c);!b||b[1].l||b[1].s||(b[1].s=!0,ra(2'
# LINE: b',a),b[1].url&&qa(b[1].url,a),b[1].libs&&D&&D(b[1].libs))},ta=function(a){B("gc",a)},ua=null,va=funct'
# LINE: b'ion(a){ua=a},ra=function(a,b,c){if(ua){a={t:a,b:b};if(c)for(var d in c)a[d]=c[d];try{ua(a)}catch(f){'
# LINE: b'}}};p("mdc",w);p("mdi",ka);p("bnc",x);p("qGC",ta);p("qm",C);p("qd",A);p("lb",sa);p("mcf",oa);p("bcf"'
# LINE: b',na);p("aq",B);p("mdd","");\np("has",pa);p("trh",va);p("tev",ra);if(h.a("m;/_/scs/abc-static/_/js/k=g'
# LINE: b'api.gapi.en.WEPncdil2Uw.O/d=1/rs=AHpOoo-eOecLLtOXEl3I3kIuMsKXRkDMmA/m=__features__")){var E=function'
# LINE: b'(a,b){return wa?a||b:b},xa=h.a("1"),ya=h.a(""),za=h.a(""),wa=h.a(""),Aa=window.gapi=E(window.gapi,{}'
# LINE: b'),Ba=function(a,b){var c=function(){g.dgl(a,b)};xa?C(c):(B("gl",c),sa("gl"))},Ca={},Da=function(a){a'
# LINE: b'=a.split(":");for(var b;(b=a.pop())&&Ca[b];);return!b},D=function(a){function b(){for(var c=a.split('
# LINE: b'":"),d,f=0;d=c[f];++f)Ca[d]=1;for(c=0;d=x[c];++c)d=d[1],(f=d.libs)&&!d.l&&d.i&&\nDa(f)&&d.i()}g.dgl(a'
# LINE: b',b)},G=window.___jsl=E(window.___jsl,{});G.h=E(G.h,"m;/_/scs/abc-static/_/js/k=gapi.gapi.en.WEPncdil'
# LINE: b'2Uw.O/d=1/rs=AHpOoo-eOecLLtOXEl3I3kIuMsKXRkDMmA/m=__features__");G.ms=E(G.ms,"https://apis.google.co'
# LINE: b'm");G.m=E(G.m,"");G.l=E(G.l,[]);G.dpo=E(G.dpo,"");xa||x.push(["gl",{url:"//ssl.gstatic.com/gb/js/abc'
# LINE: b'/glm_e7bb39a7e1a24581ff4f8d199678b1b9.js"}]);var Ea={pu:ya,sh:"",si:za,hl:"en"};w.gl=Ea;wa?Aa.load||'
# LINE: b'p("load",Ba,Aa):p("load",Ba,Aa);p("dgl",Ba);p("agl",Da);h.o=xa};var Fa=h.b("0.1",.001),Ga=0;\nfunctio'
# LINE: b'n _mlToken(a,b){try{if(1>Ga){Ga++;var c=a;b=b||{};var d=encodeURIComponent,f=["//www.google.com/gen_'
# LINE: b'204?atyp=i&zx=",(new Date).getTime(),"&jexpid=",d("28834"),"&srcpg=",d("prop=1"),"&jsr=",Math.round('
# LINE: b'1/Fa),"&ogev=",d("7rW6Y7mCHpaK0PEPjJKT4Ao"),"&ogf=",g.bv.f,"&ogrp=",d(""),"&ogv=",d("494597754.0"),"'
# LINE: b'&oggv="+d("es_plusone_gc_20221206.0_p0"),"&ogd=",d("com"),"&ogc=",d("AUS"),"&ogl=",d("en")];b._sn&&('
# LINE: b'b._sn=\n"og."+b._sn);for(var k in b)f.push("&"),f.push(d(k)),f.push("="),f.push(d(b[k]));f.push("&ems'
# LINE: b'g=");f.push(d(c.name+":"+c.message));var l=f.join("");Ha(l)&&(l=l.substr(0,2E3));var n=l;var m=windo'
# LINE: b'w.gbar.logger._aem(a,n);ja(m)}}catch(q){}}var Ha=function(a){return 2E3<=a.length},Ia=function(a,b){'
# LINE: b'return b};function Ja(a){t=a;p("_itl",Ha,v);p("_aem",Ia,v);p("ml",t,v);a={};w.er=a}h.a("")?Ja(functi'
# LINE: b'on(a){throw a;}):h.a("1")&&Math.random()<Fa&&Ja(_mlToken);var _E="left",Ka=h.a(""),La=h.a(""),I=func'
# LINE: b'tion(a,b){var c=a.className;H(a,b)||(a.className+=(""!=c?" ":"")+b)},J=function(a,b){var c=a.classNa'
# LINE: b'me;b=new RegExp("\\\\s?\\\\b"+b+"\\\\b");c&&c.match(b)&&(a.className=c.replace(b,""))},H=function(a,b){b=n'
# LINE: b'ew RegExp("\\\\b"+b+"\\\\b");a=a.className;return!(!a||!a.match(b))},Ma=function(a,b){H(a,b)?J(a,b):I(a,'
# LINE: b'b)},Na=function(a,b){a[b]=function(c){var d=arguments;g.qm(function(){a[b].apply(this,d)})}},Oa=func'
# LINE: b'tion(a){a=\n[La?"":"https://www.gstatic.com","/og/_/js/d=1/k=","og.og2.en_US.A8T3COQ4RsY.es5.O","/rt='
# LINE: b'j/m=",a,"/rs=","AA2YrTvAiqonAhzXacfGUW6KwY_BGFsbgA"];Ka&&a.push("?host=www.gstatic.com&bust=og.og2.e'
# LINE: b'n_US.s5XCRE1WvO0.es5.DU");a=a.join("");qa(a)};p("ca",I);p("cr",J);p("cc",H);h.k=I;h.l=J;h.m=H;h.n=Ma'
# LINE: b';h.p=Oa;h.q=Na;var Pa=["gb_71","gb_155"],Qa;function Ra(a){Qa=a}function Sa(a){var b=Qa&&!a.href.mat'
# LINE: b'ch(/.*\\/accounts\\/ClearSID[?]/)&&encodeURIComponent(Qa());b&&(a.href=a.href.replace(/([?&]continue=)'
# LINE: b'[^&]*/,"$1"+b))}function Ta(a){window.gApplication&&(a.href=window.gApplication.getTabUrl(a.href))}f'
# LINE: b'unction Ua(a){try{var b=(document.forms[0].q||"").value;b&&(a.href=a.href.replace(/([?&])q=[^&]*|$/,'
# LINE: b'function(c,d){return(d||"&")+"q="+encodeURIComponent(b)}))}catch(c){r(c,"sb","pq")}}\nvar Va=function'
# LINE: b'(){for(var a=[],b,c=0;b=Pa[c];++c)(b=document.getElementById(b))&&a.push(b);return a},Wa=function(){'
# LINE: b'var a=Va();return 0<a.length?a[0]:null},Xa=function(){return document.getElementById("gb_70")},K={},'
# LINE: b'L={},Ya={},M={},N=void 0,cb=function(a,b){try{var c=document.getElementById("gb");I(c,"gbpdjs");O();'
# LINE: b'Za(document.getElementById("gb"))&&I(c,"gbrtl");if(b&&b.getAttribute){var d=b.getAttribute("aria-own'
# LINE: b's");if(d.length){var f=document.getElementById(d);if(f){var k=b.parentNode;if(N==d)N=void 0,\nJ(k,"gb'
# LINE: b'to");else{if(N){var l=document.getElementById(N);if(l&&l.getAttribute){var n=l.getAttribute("aria-ow'
# LINE: b'ner");if(n.length){var m=document.getElementById(n);m&&m.parentNode&&J(m.parentNode,"gbto")}}}$a(f)&'
# LINE: b'&ab(f);N=d;I(k,"gbto")}}}}C(function(){g.tg(a,b,!0)});bb(a)}catch(q){r(q,"sb","tg")}},db=function(a)'
# LINE: b'{C(function(){g.close(a)})},eb=function(a){C(function(){g.rdd(a)})},Za=function(a){var b,c=document.'
# LINE: b'defaultView;c&&c.getComputedStyle?(a=c.getComputedStyle(a,""))&&(b=a.direction):b=a.currentStyle?\na.'
# LINE: b'currentStyle.direction:a.style.direction;return"rtl"==b},gb=function(a,b,c){if(a)try{var d=document.'
# LINE: b'getElementById("gbd5");if(d){var f=d.firstChild,k=f.firstChild,l=document.createElement("li");l.clas'
# LINE: b'sName=b+" gbmtc";l.id=c;a.className="gbmt";l.appendChild(a);if(k.hasChildNodes()){c=[["gbkc"],["gbf"'
# LINE: b',"gbe","gbn"],["gbkp"],["gbnd"]];d=0;var n=k.childNodes.length;f=!1;for(var m=-1,q,S=0;q=c[S];S++){f'
# LINE: b'or(var F=void 0,T=0;F=q[T];T++){for(;d<n&&H(k.childNodes[d],F);)d++;if(F==b){k.insertBefore(l,k.chil'
# LINE: b'dNodes[d]||\nnull);f=!0;break}}if(f){if(d+1<k.childNodes.length){var U=k.childNodes[d+1];H(U.firstChi'
# LINE: b'ld,"gbmh")||fb(U,q)||(m=d+1)}else if(0<=d-1){var V=k.childNodes[d-1];H(V.firstChild,"gbmh")||fb(V,q)'
# LINE: b'||(m=d)}break}0<d&&d+1<n&&d++}if(0<=m){var y=document.createElement("li"),z=document.createElement("'
# LINE: b'div");y.className="gbmtc";z.className="gbmt gbmh";y.appendChild(z);k.insertBefore(y,k.childNodes[m])'
# LINE: b'}g.addHover&&g.addHover(a)}else k.appendChild(l)}}catch(Bb){r(Bb,"sb","al")}},fb=function(a,b){for(v'
# LINE: b'ar c=b.length,\nd=0;d<c;d++)if(H(a,b[d]))return!0;return!1},hb=function(a,b,c){gb(a,b,c)},ib=function'
# LINE: b'(a,b){gb(a,"gbe",b)},jb=function(){C(function(){g.pcm&&g.pcm()})},kb=function(){C(function(){g.pca&&'
# LINE: b'g.pca()})},lb=function(a,b,c,d,f,k,l,n,m,q){C(function(){g.paa&&g.paa(a,b,c,d,f,k,l,n,m,q)})},mb=fun'
# LINE: b'ction(a,b){K[a]||(K[a]=[]);K[a].push(b)},nb=function(a,b){L[a]||(L[a]=[]);L[a].push(b)},ob=function('
# LINE: b'a,b){Ya[a]=b},pb=function(a,b){M[a]||(M[a]=[]);M[a].push(b)},bb=function(a){a.preventDefault&&a.prev'
# LINE: b'entDefault();a.returnValue=\n!1;a.cancelBubble=!0},qb=null,ab=function(a,b){O();if(a){rb(a,"Opening&h'
# LINE: b'ellip;");P(a,!0);b="undefined"!=typeof b?b:1E4;var c=function(){sb(a)};qb=window.setTimeout(c,b)}},t'
# LINE: b'b=function(a){O();a&&(P(a,!1),rb(a,""))},sb=function(a){try{O();var b=a||document.getElementById(N);'
# LINE: b'b&&(rb(b,"This service is currently unavailable.%1$sPlease try again later.","%1$s"),P(b,!0))}catch('
# LINE: b'c){r(c,"sb","sdhe")}},rb=function(a,b,c){if(a&&b){var d=$a(a);if(d){if(c){d.textContent="";b=b.split'
# LINE: b'(c);for(var f=0;c=b[f];f++){var k=document.createElement("div");\nk.innerHTML=c;d.appendChild(k)}}els'
# LINE: b'e d.innerHTML=b;P(a,!0)}}},P=function(a,b){(b=void 0!==b?b:!0)?I(a,"gbmsgo"):J(a,"gbmsgo")},$a=funct'
# LINE: b'ion(a){for(var b,c=0;b=a.childNodes[c];c++)if(H(b,"gbmsg"))return b},O=function(){qb&&window.clearTi'
# LINE: b'meout(qb)},ub=function(a){var b="inner"+a;a="offset"+a;return window[b]?window[b]:document.documentE'
# LINE: b'lement&&document.documentElement[a]?document.documentElement[a]:0},vb=function(){return!1},wb=functi'
# LINE: b'on(){return!!N};p("so",Wa);p("sos",Va);p("si",Xa);p("tg",cb);\np("close",db);p("rdd",eb);p("addLink",'
# LINE: b'hb);p("addExtraLink",ib);p("pcm",jb);p("pca",kb);p("paa",lb);p("ddld",ab);p("ddrd",tb);p("dderr",sb)'
# LINE: b';p("rtl",Za);p("op",wb);p("bh",K);p("abh",mb);p("dh",L);p("adh",nb);p("ch",M);p("ach",pb);p("eh",Ya)'
# LINE: b';p("aeh",ob);ba=h.a("")?Ta:Ua;p("qs",ba);p("setContinueCb",Ra);p("pc",Sa);p("bsy",vb);h.d=bb;h.j=ub;'
# LINE: b'var xb={};w.base=xb;x.push(["m",{url:"//ssl.gstatic.com/gb/js/sem_2e672151e964111a2c895f7706b9eaa2.j'
# LINE: b's"}]);g.sg={c:"1"};p("wg",{rg:{}});var yb={tiw:h.c("15000",0),tie:h.c("30000",0)};w.wg=yb;var zb={th'
# LINE: b'i:h.c("10000",0),thp:h.c("180000",0),tho:h.c("5000",0),tet:h.b("0.5",0)};w.wm=zb;if(h.a("1")){var Ab'
# LINE: b'=h.a("");x.push(["gc",{auto:Ab,url:"//ssl.gstatic.com/gb/js/abc/gci_91f30755d6a6b787dcc2a4062e6e9824'
# LINE: b'.js",libs:"googleapis.client:gapi.iframes"}]);var Cb={version:"gci_91f30755d6a6b787dcc2a4062e6e9824.'
# LINE: b'js",index:"",lang:"en"};w.gc=Cb;var Db=function(a){window.googleapis&&window.iframes?a&&a():(a&&ta(a'
# LINE: b'),sa("gc"))};p("lGC",Db);h.a("1")&&p("lPWF",Db)};window.__PVT="";var Eb=[1,2,3,4,5,6,9,10,11,13,14,2'
# LINE: b'8,29,30,34,35,37,38,39,40,41,42,43,48,49,500];var Fb=h.b("0.001",1E-4),Gb=h.b("1",1),Hb=!1,Ib=!1;if('
# LINE: b'h.a("1")){var Jb=Math.random();Jb<Fb&&(Hb=!0);Jb<Gb&&(Ib=!0)}var Q=null;\nfunction Kb(a,b){var c=Fb,d'
# LINE: b'=Hb;var f=a;if(!Q){Q={};for(var k=0;k<Eb.length;k++){var l=Eb[k];Q[l]=!0}}if(f=!!Q[f])c=Gb,d=Ib;if(d'
# LINE: b'){d=encodeURIComponent;if(g.rp){var n=g.rp();n="-1"!=n?n:""}else n="";f=(new Date).getTime();k=d("28'
# LINE: b'834");l=d("7rW6Y7mCHpaK0PEPjJKT4Ao");var m=g.bv.f,q=d("1");n=d(n);c=Math.round(1/c);var S=d("4945977'
# LINE: b'54.0"),F="&oggv="+d("es_plusone_gc_20221206.0_p0"),T=d("com"),U=d("en"),V=\nd("AUS");var y=0;h.a('
# LINE: b'"")&&(y|=1);h.a("")&&(y|=2);h.a("")&&(y|=4);a=["//www.google.com/gen_204?atyp=i&zx=",f,"&oge=",a,"&o'
# LINE: b'gex=",k,"&ogev=",l,"&ogf=",m,"&ogp=",q,"&ogrp=",n,"&ogsr=",c,"&ogv=",S,F,"&ogd=",T,"&ogl=",U,"&ogc="'
# LINE: b',V,"&ogus=",y];if(b){"ogw"in b&&(a.push("&ogw="+b.ogw),delete b.ogw);f=[];for(z in b)0!=f.length&&f.'
# LINE: b'push(","),f.push(Lb(z)),f.push("."),f.push(Lb(b[z]));var z=f.join("");""!=z&&(a.push("&ogad="),a.pus'
# LINE: b'h(d(z)))}ja(a.join(""))}}\nfunction Lb(a){"number"==typeof a&&(a+="");return"string"==typeof a?a.repl'
# LINE: b'ace(".","%2E").replace(",","%2C"):a}u=Kb;p("il",u,v);var Mb={};w.il=Mb;var Nb=function(a,b,c,d,f,k,l'
# LINE: b',n,m,q){C(function(){g.paa(a,b,c,d,f,k,l,n,m,q)})},Ob=function(){C(function(){g.prm()})},Pb=function'
# LINE: b'(a){C(function(){g.spn(a)})},Qb=function(a){C(function(){g.sps(a)})},Rb=function(a){C(function(){g.s'
# LINE: b'pp(a)})},Sb={"27":"https://lh3.googleusercontent.com/ogw/default-user=s24","27":"https://lh3.googleu'
# LINE: b'sercontent.com/ogw/default-user=s24","27":"https://lh3.googleusercontent.com/ogw/default-user=s24"},'
# LINE: b'Tb=function(a){return(a=Sb[a])||"https://lh3.googleusercontent.com/ogw/default-user=s24"},\nUb=functi'
# LINE: b'on(){C(function(){g.spd()})};p("spn",Pb);p("spp",Rb);p("sps",Qb);p("spd",Ub);p("paa",Nb);p("prm",Ob)'
# LINE: b';mb("gbd4",Ob);\nif(h.a("")){var Vb={d:h.a(""),e:"",sanw:h.a(""),p:"https://lh3.googleusercontent.com'
# LINE: b'/ogw/default-user=s96",cp:"1",xp:h.a("1"),mg:"%1$s (delegated)",md:"%1$s (default)",mh:"220",s:"1",p'
# LINE: b'p:Tb,ppl:h.a(""),ppa:h.a(""),\nppm:"Google+ page"};w.prf=Vb};var R,Wb,W,Xb,X=0,Yb=function(a,b,c){if('
# LINE: b'a.indexOf)return a.indexOf(b,c);if(Array.indexOf)return Array.indexOf(a,b,c);for(c=null==c?0:0>c?Mat'
# LINE: b'h.max(0,a.length+c):c;c<a.length;c++)if(c in a&&a[c]===b)return c;return-1},Y=function(a,b){return-1'
# LINE: b'==Yb(a,X)?(r(Error(X+"_"+b),"up","caa"),!1):!0},$b=function(a,b){Y([1,2],"r")&&(R[a]=R[a]||[],R[a].p'
# LINE: b'ush(b),2==X&&window.setTimeout(function(){b(Zb(a))},0))},ac=function(a,b,c){if(Y([1],"nap")&&c){for('
# LINE: b'var d=0;d<c.length;d++)Wb[c[d]]=!0;g.up.spl(a,b,"nap",c)}},bc=\nfunction(a,b,c){if(Y([1],"aop")&&c){i'
# LINE: b'f(W)for(var d in W)W[d]=W[d]&&-1!=Yb(c,d);else for(W={},d=0;d<c.length;d++)W[c[d]]=!0;g.up.spl(a,b,"'
# LINE: b'aop",c)}},cc=function(){try{if(X=2,!Xb){Xb=!0;for(var a in R)for(var b=R[a],c=0;c<b.length;c++)try{b'
# LINE: b'[c](Zb(a))}catch(d){r(d,"up","tp")}}}catch(d){r(d,"up","mtp")}},Zb=function(a){if(Y([2],"ssp")){var '
# LINE: b'b=!Wb[a];W&&(b=b&&!!W[a]);return b}};Xb=!1;R={};Wb={};W=null;X=1;\nvar dc=function(a){var b=!1;try{b='
# LINE: b'a.cookie&&a.cookie.match("PREF")}catch(c){}return!b},ec=function(){try{return!!e.localStorage&&"obje'
# LINE: b'ct"==typeof e.localStorage}catch(a){return!1}},fc=function(a){return a&&a.style&&a.style.behavior&&"'
# LINE: b'undefined"!=typeof a.load},gc=function(a,b,c,d){try{dc(document)||(d||(b="og-up-"+b),ec()?e.localSto'
# LINE: b'rage.setItem(b,c):fc(a)&&(a.setAttribute(b,c),a.save(a.id)))}catch(f){f.code!=DOMException.QUOTA_EXC'
# LINE: b'EEDED_ERR&&r(f,"up","spd")}},hc=function(a,b,c){try{if(dc(document))return"";\nc||(b="og-up-"+b);if(e'
# LINE: b'c())return e.localStorage.getItem(b);if(fc(a))return a.load(a.id),a.getAttribute(b)}catch(d){d.code!'
# LINE: b'=DOMException.QUOTA_EXCEEDED_ERR&&r(d,"up","gpd")}return""},ic=function(a,b,c){a.addEventListener?a.'
# LINE: b'addEventListener(b,c,!1):a.attachEvent&&a.attachEvent("on"+b,c)},jc=function(a){for(var b,c=0;b=a[c]'
# LINE: b';c++){var d=g.up;b=b in d&&d[b];if(!b)return!1}return!0},kc=function(a,b){try{if(dc(a))return-1;var '
# LINE: b'c=a.cookie.match(/OGPC=([^;]*)/);if(c&&c[1]){var d=c[1].match(new RegExp("\\\\b"+\nb+"-([0-9]+):"));if('
# LINE: b'd&&d[1])return parseInt(d[1],10)}}catch(f){f.code!=DOMException.QUOTA_EXCEEDED_ERR&&r(f,"up","gcc")}'
# LINE: b'return-1};p("up",{r:$b,nap:ac,aop:bc,tp:cc,ssp:Zb,spd:gc,gpd:hc,aeh:ic,aal:jc,gcc:kc});var Z=functio'
# LINE: b'n(a,b){a[b]=function(c){var d=arguments;g.qm(function(){a[b].apply(this,d)})}};Z(g.up,"sl");Z(g.up,"'
# LINE: b'si");Z(g.up,"spl");Z(g.up,"dpc");Z(g.up,"iic");g.mcf("up",{sp:h.b("0.01",1),tld:"com.au",prid:"1"});'
# LINE: b'function lc(){function a(){for(var m;(m=k[l++])&&"m"!=m[0]&&!m[1].auto;);m&&(ra(2,m[0]),m[1].url&&qa'
# LINE: b'(m[1].url,m[0]),m[1].libs&&D&&D(m[1].libs));l<k.length&&setTimeout(a,0)}function b(){0<f--?setTimeou'
# LINE: b't(b,0):a()}var c=h.a("1"),d=h.a(""),f=3,k=x,l=0,n=window.gbarOnReady;if(n)try{n()}catch(m){r(m,"ml",'
# LINE: b'"or")}d?p("ldb",a):c?ca(window,"load",b):b()}p("rdl",lc);}catch(e){window.gbar&&gbar.logger&&gbar.lo'
# LINE: b'gger.ml(e,{"_sn":"cfg.init"});}})();\n(function(){try{var b=window.gbar.i.i;var c=window.gbar;var f=f'
# LINE: b'unction(d){try{var a=document.getElementById("gbom");a&&d.appendChild(a.cloneNode(!0))}catch(e){b(e,'
# LINE: b'"omas","aomc")}};c.aomc=f;}catch(e){window.gbar&&gbar.logger&&gbar.logger.ml(e,{"_sn":"cfg.init"});}'
# LINE: b'})();\n(function(){try{var a=window.gbar;a.mcf("pm",{p:"19028915,7X7,7,,"});}catch(e){window.gbar&&gb'
# LINE: b'ar.logger&&gbar.logger.ml(e,{"_sn":"cfg.init"});}})();\n(function(){try{var a=window.gbar;a.mcf("mm",'
# LINE: b'{s:"1"});}catch(e){window.gbar&&gbar.logger&&gbar.logger.ml(e,{"_sn":"cfg.init"});}})();\n(function()'
# LINE: b'{try{var d=window.gbar.i.i;var e=window.gbar;var f=e.i;var g=f.c("1",0),h=/\\bgbmt\\b/,k=function(a){t'
# LINE: b'ry{var b=document.getElementById("gb_"+g),c=document.getElementById("gb_"+a);b&&f.l(b,h.test(b.class'
# LINE: b'Name)?"gbm0l":"gbz0l");c&&f.k(c,h.test(c.className)?"gbm0l":"gbz0l")}catch(l){d(l,"sj","ssp")}g=a},m'
# LINE: b'=e.qs,n=function(a){var b=a.href;var c=window.location.href.match(/.*?:\\/\\/[^\\/]*/)[0];c=new RegExp('
# LINE: b'"^"+c+"/search\\\\?");(b=c.test(b))&&!/(^|\\\\?|&)ei=/.test(a.href)&&(b=window.google)&&b.kEXPI&&(a.href'
# LINE: b'+="&ei="+b.kEI)},p=function(a){m(a);\nn(a)},q=function(){if(window.google&&window.google.sn){var a=/.'
# LINE: b'*hp$/;return a.test(window.google.sn)?"":"1"}return"-1"};e.rp=q;e.slp=k;e.qs=p;e.qsi=n;}catch(e){win'
# LINE: b'dow.gbar&&gbar.logger&&gbar.logger.ml(e,{"_sn":"cfg.init"});}})();\n(function(){try{/*\n\n Copyright Th'
# LINE: b'e Closure Library Authors.\n SPDX-License-Identif'
# LINE: b'ier: Apache-2.0\n*/\nvar a=this||self;var b=window.gbar;var c=b.i;var d=c.a,e=c.c,f={cty:"AUS",cv:"494'
# LINE: b'597754",dbg:d(""),ecv:"0",ei:e("7rW6Y7mCHpaK0PEPjJKT4Ao"),ele:d("1"),esr:e("0.1"),evts:["mousedown",'
# LINE: b'"touchstart","touchmove","wheel","keydown"],gbl:"es_plusone_gc_20221206.0_p0",hd:"com",hl:"en",irp:d'
# LINE: b'(""),pid:e("1"),\nsnid:e("28834"),to:e("300000"),u:e(""),vf:".66."},g=f,h=["bndcfg"],k=a;h[0]in k||"u'
# LINE: b'ndefined"==typeof k.execScript||k.execScript("var "+h[0]);for(var l;h.length&&(l=h.shift());)h.lengt'
# LINE: b'h||void 0===g?k=k[l]&&k[l]!==Object.prototype[l]?k[l]:k[l]={}:k[l]=g;}catch(e){window.gbar&&gbar.log'
# LINE: b'ger&&gbar.logger.ml(e,{"_sn":"cfg.init"});}})();\n(function(){try{window.gbar.rdl();}catch(e){window.'
# LINE: b'gbar&&gbar.logger&&gbar.logger.ml(e,{"_sn":"cfg.init"});}})();\n</script></head><body bgcolor="#fff">'
# LINE: b'<script nonce="-uf_P2wfcPOZsT_bJhByqA">(function(){var src=\'/images/nav_logo229.png\';var iesg=false;'
# LINE: b'document.body.onload = function(){window.n && window.n();if (document.images){new Image().src=src;}\n'
# LINE: b'if (!iesg){document.f&&document.f.q.focus();document.gbqf&&document.gbqf.q.focus();}\n}\n})();</script'
# LINE: b'><div id="mngb"><div id=gb><script nonce=\'-uf_P2wfcPOZsT_bJhByqA\'>window.gbar&&gbar.eli&&gbar.eli()<'
# LINE: b'/script><div id=gbw><div id=gbz><span class=gbtcb></span><ol id=gbzc class=gbtc><li class=gbt><a cla'
# LINE: b'ss="gbzt gbz0l gbp1" id=gb_1 href="https://www.google.com.au/webhp?tab=ww"><span class=gbtb2></span>'
# LINE: b'<span class=gbts>Search</span></a></li><li class=gbt><a class=gbzt id=gb_2 href="http://www.google.c'
# LINE: b'om.au/imghp?hl=en&tab=wi"><span class=gbtb2></span><span class=gbts>Images</span></a></li><li class='
# LINE: b'gbt><a class=gbzt id=gb_8 href="http://maps.google.com.au/maps?hl=en&tab=wl"><span class=gbtb2></spa'
# LINE: b'n><span class=gbts>Maps</span></a></li><li class=gbt><a class=gbzt id=gb_78 href="https://play.googl'
# LINE: b'e.com/?hl=en&tab=w8"><span class=gbtb2></span><span class=gbts>Play</span></a></li><li class=gbt><a '
# LINE: b'class=gbzt id=gb_36 href="https://www.youtube.com/?tab=w1"><span class=gbtb2></span><span class=gbts'
# LINE: b'>YouTube</span></a></li><li class=gbt><a class=gbzt id=gb_426 href="https://news.google.com/?tab=wn"'
# LINE: b'><span class=gbtb2></span><span class=gbts>News</span></a></li><li class=gbt><a class=gbzt id=gb_23 '
# LINE: b'href="https://mail.google.com/mail/?tab=wm"><span class=gbtb2></span><span class=gbts>Gmail</span></'
# LINE: b'a></li><li class=gbt><a class=gbzt id=gb_49 href="https://drive.google.com/?tab=wo"><span class=gbtb'
# LINE: b'2></span><span class=gbts>Drive</span></a></li><li class=gbt><a class=gbgt id=gbztm href="https://ww'
# LINE: b'w.google.com.au/intl/en/about/products?tab=wh"  aria-haspopup=true aria-owns=gbd><span class=gbtb2><'
# LINE: b'/span><span id=gbztms class="gbts gbtsa"><span id=gbztms1>More</span><span class=gbma></span></span>'
# LINE: b"</a><script nonce='-uf_P2wfcPOZsT_bJhByqA'>document.getElementById('gbztm').addEventListener('click'"
# LINE: b', function clickHandler() { gbar.tg(event,this); });</script><div class=gbm id=gbd aria-owner=gbztm>'
# LINE: b'<div id=gbmmb class="gbmc gbsb gbsbis"><ol id=gbmm class="gbmcc gbsbic"><li class=gbmtc><a class=gbm'
# LINE: b't id=gb_24 href="https://calendar.google.com/calendar?tab=wc">Calendar</a></li><li class=gbmtc><a cl'
# LINE: b'ass=gbmt id=gb_51 href="https://translate.google.com.au/?hl=en&tab=wT">Translate</a></li><li class=g'
# LINE: b'bmtc><a class=gbmt id=gb_10 href="https://books.google.com.au/?hl=en&tab=wp">Books</a></li><li class'
# LINE: b'=gbmtc><a class=gbmt id=gb_6 href="https://www.google.com.au/shopping?hl=en&source=og&tab=wf">Shoppi'
# LINE: b'ng</a></li><li class=gbmtc><a class=gbmt id=gb_30 href="http://www.blogger.com/?tab=wj">Blogger</a><'
# LINE: b'/li><li class=gbmtc><a class=gbmt id=gb_27 href="https://www.google.com/finance?tab=we">Finance</a><'
# LINE: b'/li><li class=gbmtc><a class=gbmt id=gb_31 href="https://photos.google.com/?tab=wq&pageId=none">Phot'
# LINE: b'os</a></li><li class=gbmtc><a class=gbmt id=gb_12 href="http://video.google.com.au/?hl=en&tab=wv">Vi'
# LINE: b'deos</a></li><li class=gbmtc><a class=gbmt id=gb_25 href="https://docs.google.com/document/?usp=docs'
# LINE: b'_alc">Docs</a></li><li class=gbmtc><div class="gbmt gbmh"></div></li><li class=gbmtc><a  href="https'
# LINE: b'://www.google.com.au/intl/en/about/products?tab=wh" class=gbmt>Even more &raquo;</a><script nonce=\'-'
# LINE: b"uf_P2wfcPOZsT_bJhByqA'>document.querySelector('li > a.gbmt').addEventListener('click', function clic"
# LINE: b'kHandler() { gbar.logger.il(1,{t:66});; });</script></li></ol><div class=gbsbt></div><div class=gbsb'
# LINE: b'b></div></div></div></li></ol></div><div id=gbg><h2 class=gbxx>Account Options</h2><span class=gbtcb'
# LINE: b'></span><ol class=gbtc><li class=gbt><a target=_top href="https://accounts.google.com/ServiceLogin?h'
# LINE: b'l=en&passive=true&continue=http://www.google.com/&ec=GAZAAQ" onclick="gbar.logger.il(9,{l:\'i\'})" id='
# LINE: b'gb_70 class=gbgt><span class=gbtb2></span><span id=gbgs4 class=gbts><span id=gbi4s1>Sign in</span></'
# LINE: b'span></a></li><li class="gbt gbtb"><span class=gbts></span></li><li class=gbt><a class=gbgt id=gbg5 '
# LINE: b'href="http://www.google.com.au/preferences?hl=en" title="Options" aria-haspopup=true aria-owns=gbd5>'
# LINE: b"<span class=gbtb2></span><span id=gbgs5 class=gbts><span id=gbi5></span></span></a><script nonce='-u"
# LINE: b"f_P2wfcPOZsT_bJhByqA'>document.getElementById('gbg5').addEventListener('click', function clickHandle"
# LINE: b'r() { gbar.tg(event,this); });</script><div class=gbm id=gbd5 aria-owner=gbg5><div class=gbmc><ol id'
# LINE: b'=gbom class=gbmcc><li class="gbkc gbmtc"><a  class=gbmt href="/preferences?hl=en">Search settings</a'
# LINE: b'></li><li class=gbmtc><div class="gbmt gbmh"></div></li><li class="gbkp gbmtc"><a class=gbmt href="h'
# LINE: b'ttp://www.google.com.au/history/optout?hl=en">Web History</a></li></ol></div></div></li></ol></div><'
# LINE: b"/div><div id=gbx3></div><div id=gbx4></div><script nonce='-uf_P2wfcPOZsT_bJhByqA'>window.gbar&&gbar."
# LINE: b'elp&&gbar.elp()</script></div></div><center><br clear="all" id="lgpd"><div id="lga"><img alt="Google'
# LINE: b'" height="92" src="/images/branding/googlelogo/1x/googlelogo_white_background_color_272x92dp.png" st'
# LINE: b'yle="padding:28px 0 14px" width="272" id="hplogo"><br><br></div><form action="/search" name="f"><tab'
# LINE: b'le cellpadding="0" cellspacing="0"><tr valign="top"><td width="25%">&nbsp;</td><td align="center" no'
# LINE: b'wrap=""><input name="ie" value="ISO-8859-1" type="hidden"><input value="en-AU" name="hl" type="hidde'
# LINE: b'n"><input name="source" type="hidden" value="hp"><input name="biw" type="hidden"><input name="bih" t'
# LINE: b'ype="hidden"><div class="ds" style="height:32px;margin:4px 0"><input class="lst" style="margin:0;pad'
# LINE: b'ding:5px 8px 0 6px;vertical-align:top;color:#000" autocomplete="off" value="" title="Google Search" '
# LINE: b'maxlength="2048" name="q" size="57"></div><br style="line-height:0"><span class="ds"><span class="ls'
# LINE: b'bb"><input class="lsb" value="Google Search" name="btnG" type="submit"></span></span><span class="ds'
# LINE: b'"><span class="lsbb"><input class="lsb" id="tsuid_1" value="I\'m Feeling Lucky" name="btnI" type="sub'
# LINE: b'mit"><script nonce="-uf_P2wfcPOZsT_bJhByqA">(function(){var id=\'tsuid_1\';document.getElementById(id)'
# LINE: b'.onclick = function(){if (this.form.q.value){this.checked = 1;if (this.form.iflsig)this.form.iflsig.'
# LINE: b'disabled = false;}\nelse top.location=\'/doodles/\';};})();</script><input value="AK50M_UAAAAAY7rD_lCSa'
# LINE: b'dUf82BXZJvnPAbCZjGhe7AV" name="iflsig" type="hidden"></span></span></td><td class="fl sblc" align="l'
# LINE: b'eft" nowrap="" width="25%"><a href="/advanced_search?hl=en-AU&amp;authuser=0">Advanced search</a></t'
# LINE: b'd></tr></table><input id="gbv" name="gbv" type="hidden" value="1"><script nonce="-uf_P2wfcPOZsT_bJhB'
# LINE: b'yqA">(function(){var a,b="1";if(document&&document.getElementById)if("undefined"!=typeof XMLHttpRequ'
# LINE: b'est)b="2";else if("undefined"!=typeof ActiveXObject){var c,d,e=["MSXML2.XMLHTTP.6.0","MSXML2.XMLHTTP'
# LINE: b'.3.0","MSXML2.XMLHTTP","Microsoft.XMLHTTP"];for(c=0;d=e[c++];)try{new ActiveXObject(d),b="2"}catch(h'
# LINE: b'){}}a=b;if("2"==a&&-1==location.search.indexOf("&gbv=2")){var f=google.gbvu,g=document.getElementByI'
# LINE: b'd("gbv");g&&(g.value=a);f&&window.setTimeout(function(){location.href=f},0)};}).call(this);</script>'
# LINE: b'</form><div id="gac_scont"></div><div style="font-size:83%;min-height:3.5em"><br></div><span id="foo'
# LINE: b'ter"><div style="font-size:10pt"><div style="margin:19px auto;text-align:center" id="WqQANb"><a href'
# LINE: b'="/intl/en/ads/">Advertising\xa0Programmes</a><a href="/services/">Business Solutions</a><a href="/intl'
# LINE: b'/en/about.html">About Google</a><a href="http://www.google.com/setprefdomain?prefdom=AU&amp;prev=htt'
# LINE: b'p://www.google.com.au/&amp;sig=K_1lTSb4eLS9aRn-pFjh2GF0Kpx1g%3D">Google.com.au</a></div></div><p sty'
# LINE: b'le="font-size:8pt;color:#70757a">&copy; 2023 - <a href="/intl/en/policies/privacy/">Privacy</a> - <a'
# LINE: b' href="/intl/en/policies/terms/">Terms</a></p></span></center><script nonce="-uf_P2wfcPOZsT_bJhByqA"'
# LINE: b'>(function(){window.google.cdo={height:757,width:1440};(function(){var a=window.innerWidth,b=window.'
# LINE: b'innerHeight;if(!a||!b){var c=window.document,d="CSS1Compat"==c.compatMode?c.documentElement:c.body;a'
# LINE: b'=d.clientWidth;b=d.clientHeight}a&&b&&(a!=google.cdo.width||b!=google.cdo.height)&&google.log("","",'
# LINE: b'"/client_204?&atyp=i&biw="+a+"&bih="+b+"&ei="+google.kEI);}).call(this);})();</script> <script nonce'
# LINE: b'="-uf_P2wfcPOZsT_bJhByqA">(function(){google.xjs={ck:\'xjs.hp.L0TU2uVtv08.L.X.O\',cs:\'ACT90oEO_R29dX-q'
# LINE: b'xyO5sbBDvB_tO-g5oA\',excm:[]};})();</script>  <script nonce="-uf_P2wfcPOZsT_bJhByqA">(function(){var '
# LINE: b"u='/xjs/_/js/k\\x3dxjs.hp.en.tri6cHVG4N4.O/am\\x3dAADoBABQAGAB/d\\x3d1/ed\\x3d1/rs\\x3dACT90oGcRY3TI3p3dn"
# LINE: b"RpfgDXY95SIvHVrw/m\\x3dsb_he,d';var amd=0;\nvar d=this||self,e=function(a){return a};var g;var l=funct"
# LINE: b'ion(a,b){this.g=b===h?a:""};l.prototype.toString=function(){return this.g+""};var h={};\nfunction m()'
# LINE: b'{var a=u;google.lx=function(){p(a);google.lx=function(){}};google.bx||google.lx()}\nfunction p(a){goo'
# LINE: b'gle.timers&&google.timers.load&&google.tick&&google.tick("load","xjsls");var b=document;var c="SCRIP'
# LINE: b'T";"application/xhtml+xml"===b.contentType&&(c=c.toLowerCase());c=b.createElement(c);a=null===a?"nul'
# LINE: b'l":void 0===a?"undefined":a;if(void 0===g){b=null;var k=d.trustedTypes;if(k&&k.createPolicy){try{b=k'
# LINE: b'.createPolicy("goog#html",{createHTML:e,createScript:e,createScriptURL:e})}catch(q){d.console&&d.con'
# LINE: b'sole.error(q.message)}g=b}else g=b}a=(b=g)?b.createScriptURL(a):a;a=new l(a,h);c.src=\na instanceof l'
# LINE: b'&&a.constructor===l?a.g:"type_error:TrustedResourceUrl";var f,n;(f=(a=null==(n=(f=(c.ownerDocument&&'
# LINE: b'c.ownerDocument.defaultView||window).document).querySelector)?void 0:n.call(f,"script[nonce]"))?a.no'
# LINE: b'nce||a.getAttribute("nonce")||"":"")&&c.setAttribute("nonce",f);document.body.appendChild(c);google.'
# LINE: b'psa=!0};google.xjsu=u;setTimeout(function(){0<amd?google.caft(function(){return m()},amd):m()},0);})'
# LINE: b"();function _DumpException(e){throw e;}\nfunction _F_installCss(c){}\n(function(){google.jl={blt:'none"
# LINE: b"',chnk:0,dw:false,dwu:true,emtn:0,end:0,ico:false,ikb:0,ine:false,injs:'none',injt:0,injth:0,injv2:f"
# LINE: b"alse,lls:'default',pdt:0,rep:0,snet:true,strt:0,ubm:false,uwp:true};})();(function(){var pmc='{\\x22d"
# LINE: b'\\x22:{},\\x22sb_he\\x22:{\\x22agen\\x22:true,\\x22cgen\\x22:true,\\x22client\\x22:\\x22heirloom-hp\\x22,\\x22dh'
# LINE: b'\\x22:true,\\x22ds\\x22:\\x22\\x22,\\x22fl\\x22:true,\\x22host\\x22:\\x22google.com\\x22,\\x22jsonp\\x22:true,\\x2'
# LINE: b'2msgs\\x22:{\\x22cibl\\x22:\\x22Clear Search\\x22,\\x22dym\\x22:\\x22Did you mean:\\x22,\\x22lcky\\x22:\\x22I\\\\u'
# LINE: b'0026#39;m Feeling Lucky\\x22,\\x22lml\\x22:\\x22Learn more\\x22,\\x22psrc\\x22:\\x22This search was removed '
# LINE: b'from your \\\\u003Ca href\\x3d\\\\\\x22/history\\\\\\x22\\\\u003EWeb History\\\\u003C/a\\\\u003E\\x22,\\x22psrl\\x22:\\'
# LINE: b'x22Remove\\x22,\\x22sbit\\x22:\\x22Search by image\\x22,\\x22srch\\x22:\\x22Google Search\\x22},\\x22ovr\\x'
# LINE: b'22:{},\\x22pq\\x22:\\x22\\x22,\\x22rfs\\x22:[],\\x22sbas\\x22:\\x220 3px 8px 0 rgba(0,0,0,0.2),0 0 0 1px rgba'
# LINE: b"(0,0,0,0.08)\\x22,\\x22stok\\x22:\\x22n6Yffr4-8VJJQl9zuzJp5PUw6lI\\x22}}';google.pmc=JSON.parse(pmc);})()"
# LINE: b';</script>        </body></html>\r\n0\r\n\r\n'
# <socket.socket [closed] fd=-1, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0>

# %%
"hello".encode('utf-8')
# Out:
# b'hello'

# %%
class MyClass:
    def __init__(self):
        self.__foo = "Hello, world!"

    def get_foo(self):
        return self.__foo

class MyDerivedClass(MyClass):
    def __init__(self):
        super().__init__()
        self.__foo = "Goodbye, world!"

# %%
dir(MyDerivedClass())
MyDerivedClass()._MyDerivedClass__foo
# Out:
# 'Goodbye, world!'

# %%
# Out:
# <enum 'SocketKind'>
