# %% [markdown]
# ## Reinforcement

# %% [markdown]
# ### R5.1
#
# <img src="DA\R51.png">
#
# **Comparing length values at which additional bytes are allocated**
#
# On both systems, additional bytes are allocated at the same length thresholds (except for length 25).
#
# **Comparing size of byte allocation**
#
# Except for lists of length 0 and 25, the same number of bytes are allocated at each length threshold.
#
# | Length Threshold |Number of additional bytes allocated|
# | ---|--- |
# | 0| Differing amount |
# |1 |32 |
# | 5| 32|
# |9 |64 |
# |17 | 64|
# |25 | 64 on my system, none on authors'|

# %%
import sys
from pandas import DataFrame

data = []
results = []
for i in range(0,27):
    length = len(data)
    bytes = sys.getsizeof(data)
    results.append({'length': length, "Size in bytes": bytes})
    data.append(None)

tabular_results = (DataFrame(results)
                .set_index('length', drop=True)
                .T
                .style.background_gradient(cmap='coolwarm', axis=1))

my_system_results = tabular_results.to_html()
display(tabular_results)
# Out:
# <style type="text/css">
# #T_c2170_row0_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c2170_row0_col1, #T_c2170_row0_col2, #T_c2170_row0_col3, #T_c2170_row0_col4 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_c2170_row0_col5, #T_c2170_row0_col6, #T_c2170_row0_col7, #T_c2170_row0_col8 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_c2170_row0_col9, #T_c2170_row0_col10, #T_c2170_row0_col11, #T_c2170_row0_col12, #T_c2170_row0_col13, #T_c2170_row0_col14, #T_c2170_row0_col15, #T_c2170_row0_col16 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_c2170_row0_col17, #T_c2170_row0_col18, #T_c2170_row0_col19, #T_c2170_row0_col20, #T_c2170_row0_col21, #T_c2170_row0_col22, #T_c2170_row0_col23, #T_c2170_row0_col24 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_c2170_row0_col25, #T_c2170_row0_col26 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c2170">
#   <thead>
#     <tr>
#       <th class="index_name level0" >length</th>
#       <th id="T_c2170_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_c2170_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_c2170_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_c2170_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_c2170_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_c2170_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_c2170_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_c2170_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_c2170_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_c2170_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_c2170_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_c2170_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_c2170_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_c2170_level0_col13" class="col_heading level0 col13" >13</th>
#       <th id="T_c2170_level0_col14" class="col_heading level0 col14" >14</th>
#       <th id="T_c2170_level0_col15" class="col_heading level0 col15" >15</th>
#       <th id="T_c2170_level0_col16" class="col_heading level0 col16" >16</th>
#       <th id="T_c2170_level0_col17" class="col_heading level0 col17" >17</th>
#       <th id="T_c2170_level0_col18" class="col_heading level0 col18" >18</th>
#       <th id="T_c2170_level0_col19" class="col_heading level0 col19" >19</th>
#       <th id="T_c2170_level0_col20" class="col_heading level0 col20" >20</th>
#       <th id="T_c2170_level0_col21" class="col_heading level0 col21" >21</th>
#       <th id="T_c2170_level0_col22" class="col_heading level0 col22" >22</th>
#       <th id="T_c2170_level0_col23" class="col_heading level0 col23" >23</th>
#       <th id="T_c2170_level0_col24" class="col_heading level0 col24" >24</th>
#       <th id="T_c2170_level0_col25" class="col_heading level0 col25" >25</th>
#       <th id="T_c2170_level0_col26" class="col_heading level0 col26" >26</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2170_level0_row0" class="row_heading level0 row0" >Size in bytes</th>
#       <td id="T_c2170_row0_col0" class="data row0 col0" >56</td>
#       <td id="T_c2170_row0_col1" class="data row0 col1" >88</td>
#       <td id="T_c2170_row0_col2" class="data row0 col2" >88</td>
#       <td id="T_c2170_row0_col3" class="data row0 col3" >88</td>
#       <td id="T_c2170_row0_col4" class="data row0 col4" >88</td>
#       <td id="T_c2170_row0_col5" class="data row0 col5" >120</td>
#       <td id="T_c2170_row0_col6" class="data row0 col6" >120</td>
#       <td id="T_c2170_row0_col7" class="data row0 col7" >120</td>
#       <td id="T_c2170_row0_col8" class="data row0 col8" >120</td>
#       <td id="T_c2170_row0_col9" class="data row0 col9" >184</td>
#       <td id="T_c2170_row0_col10" class="data row0 col10" >184</td>
#       <td id="T_c2170_row0_col11" class="data row0 col11" >184</td>
#       <td id="T_c2170_row0_col12" class="data row0 col12" >184</td>
#       <td id="T_c2170_row0_col13" class="data row0 col13" >184</td>
#       <td id="T_c2170_row0_col14" class="data row0 col14" >184</td>
#       <td id="T_c2170_row0_col15" class="data row0 col15" >184</td>
#       <td id="T_c2170_row0_col16" class="data row0 col16" >184</td>
#       <td id="T_c2170_row0_col17" class="data row0 col17" >248</td>
#       <td id="T_c2170_row0_col18" class="data row0 col18" >248</td>
#       <td id="T_c2170_row0_col19" class="data row0 col19" >248</td>
#       <td id="T_c2170_row0_col20" class="data row0 col20" >248</td>
#       <td id="T_c2170_row0_col21" class="data row0 col21" >248</td>
#       <td id="T_c2170_row0_col22" class="data row0 col22" >248</td>
#       <td id="T_c2170_row0_col23" class="data row0 col23" >248</td>
#       <td id="T_c2170_row0_col24" class="data row0 col24" >248</td>
#       <td id="T_c2170_row0_col25" class="data row0 col25" >312</td>
#       <td id="T_c2170_row0_col26" class="data row0 col26" >312</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### R-5.2
#
# <img src='DA\r52.png'>

# %%
import sys

data = []
array_sizes_at_max_capacity = []
allocated_bytes = sys.getsizeof(data)

for array_size in range(1,26):
    data.append(None)
    # If the array had to resize to fit the new element, then capacity was 
    # exhausted at the previous size of the array.
    if allocated_bytes != (allocated_bytes := sys.getsizeof(data)):
        array_sizes_at_max_capacity.append(array_size -1) 

print(array_sizes_at_max_capacity)
# Out:
# [0, 4, 8, 16, 24]

# %% [markdown]
# ### R-5.3

# %%
import sys
from pandas import DataFrame
import math

data = []
results = []
allocated_bytes = sys.getsizeof(data)

for array_size in range(1,501):
    data.append(None)
    change_in_bytes = abs(allocated_bytes - (allocated_bytes := sys.getsizeof(data)))
    if change_in_bytes:
        results.append(
            {"length": array_size, 
             "bytes": allocated_bytes,
            "change of bytes": change_in_bytes,
            "log_2(change of bytes)": math.log2(change_in_bytes)
        })

for array_size in range(499,0, -1):
    data.pop()
    change_in_bytes = allocated_bytes - (allocated_bytes := sys.getsizeof(data))
    if change_in_bytes:
        results.append(
            {"length": array_size, 
             "bytes": allocated_bytes,
            "change of bytes": - change_in_bytes,
             "log_2(change of bytes)": math.log2(change_in_bytes) 
        })

tabulated_results = DataFrame(results)

tabulated_results
# Out:
#     length  bytes  change of bytes  log_2(change of bytes)
# 0        1     88               32                5.000000
# 1        5    120               32                5.000000
# 2        9    184               64                6.000000
# 3       17    248               64                6.000000
# 4       25    312               64                6.000000
# 5       33    376               64                6.000000
# 6       41    472               96                6.584963
# 7       53    568               96                6.584963
# 8       65    664               96                6.584963
# 9       77    792              128                7.000000
# 10      93    920              128                7.000000
# 11     109   1080              160                7.321928
# 12     129   1240              160                7.321928
# 13     149   1432              192                7.584963
# 14     173   1656              224                7.807355
# 15     201   1912              256                8.000000
# 16     233   2200              288                8.169925
# 17     269   2520              320                8.321928
# 18     309   2872              352                8.459432
# 19     353   3256              384                8.584963
# 20     401   3704              448                8.807355
# 21     457   4216              512                9.000000
# 22     259   2424            -1792               10.807355
# 23     147   1400            -1024               10.000000
# 24      83    824             -576                9.169925
# 25      47    504             -320                8.321928
# 26      27    344             -160                7.321928
# 27      17    248              -96                6.584963
# 28      11    184              -64                6.000000
# 29       7    152              -32                5.000000
# 30       5    120              -32                5.000000
# 31       1     88              -32                5.000000

# %%
import sys


def array_grow_shrink(n, lower_limit = 0.2):
    data = []
    size_old = 0
    current_limit = 10
    for i in range(n):
        if i == current_limit:
            while len(data)> current_limit*lower_limit:
                data.pop()
                size = sys.getsizeof(data)
                print(len(data), size, end = '\t\t')
                if size<size_old:
                    print ('Size decreased from:', size_old, size)
                else: print("")
                size_old = size
            current_limit *= 10
        data.append(None)
        
        
array_grow_shrink(11)
# Out:
# 9 184
# 8 184
# 7 152		Size decreased from: 184 152
# 6 152
# 5 120		Size decreased from: 152 120
# 4 120
# 3 120
# 2 120
